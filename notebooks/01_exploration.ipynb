# %% [markdown]
# # Biotech Earnings NLP Exploration
# Quick-start notebook to explore sentiment and event returns.

# %%
import pandas as pd
from pathlib import Path
from src.analysis.eda import load_events_with_features, plot_histograms, plot_scatter_sentiment_vs_returns, plot_box_by_sentiment_bucket

CONFIG_PATH = Path('config/config.yaml')
df = load_events_with_features(CONFIG_PATH)

plot_histograms(df)
plot_scatter_sentiment_vs_returns(df)
plot_box_by_sentiment_bucket(df)
